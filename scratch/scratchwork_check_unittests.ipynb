# %% [markdown]
# # Check Unittests

# %%
import finalg as fg
from finalg.element import Element

# %%
fg.examples.about()
# Out:
# ...
#                            Example Algebras
# ----------------------------------------------------------------------
#   20 example algebras are available.
#   The INDEX is the first number on each line below:
# ----------------------------------------------------------------------
# 0: A4 -- Alternating group on 4 letters (AKA Tetrahedral group)
# 1: D3 -- https://en.wikipedia.org/wiki/Dihedral_group_of_order_6
# 2: D4 -- Dihedral group on four vertices
# 3: Pinter29 -- Non-abelian group, p.29, 'A Book of Abstract Algebra' by Charles C. Pinter
# 4: RPS -- Rock, Paper, Scissors Magma
# 5: S3 -- Symmetric group on 3 letters
# 6: S3X -- Another version of the symmetric group on 3 letters
# 7: V4 -- Klein-4 group
# 8: Z4 -- Cyclic group of order 4
# 9: F4 -- Field with 4 elements (from Wikipedia)
# 10: mag_id -- Magma with Identity
# 11: Example 1.4.1 -- See: Groupoids and Smarandache Groupoids by W. B. Vasantha Kandasamy
# ...

# %%
v4 = fg.examples[7]
rps = fg.examples[4]

# %%
v4
# Out:
# Group(
# 'V4',
# 'Klein-4 group',
# ('e', 'h', 'v', 'r'),
# [[0, 1, 2, 3], [1, 0, 3, 2], [2, 3, 0, 1], [3, 2, 1, 0]]
# )

# %%
rps
# Out:
# Magma(
# 'RPS',
# 'Rock, Paper, Scissors Magma',
# ('r', 'p', 's'),
# [[0, 1, 0], [1, 1, 2], [0, 2, 2]]
# )

# %%
v4.element_map()
# Out:
# {'e': <V4:e>, 'h': <V4:h>, 'v': <V4:v>, 'r': <V4:r>}

# %%
def make_v4():
    return fg.make_finite_algebra('V4', 'Klein-4 group', ['e', 'h', 'v', 'r'],
                                [[0, 1, 2, 3], [1, 0, 3, 2], [2, 3, 0, 1], [3, 2, 1, 0]])

# %%
v4 = make_v4()
v4
# Out:
# Group(
# 'V4',
# 'Klein-4 group',
# ('e', 'h', 'v', 'r'),
# [[0, 1, 2, 3], [1, 0, 3, 2], [2, 3, 0, 1], [3, 2, 1, 0]]
# )

# %%
v4.element_map()
# Out:
# {'e': <V4:e>, 'h': <V4:h>, 'v': <V4:v>, 'r': <V4:r>}

# %%
z4 = fg.generate_cyclic_group(4)

# %%
e = Element('2', z4)
e
# Out:
# <Z4:2>

# %%
rps.identity is None
# Out:
# True
